# %%
import pandas as pd
from pyhive import hive

# %%
connection = hive.Connection('localhost', 10000)

# %%
df = pd.read_sql('select * from artist_table limit 5', connection)

# %%
df.head()
# Out:
#                       artist_table.mbid artist_table.artist_mb  \
# 0                                  mbid              artist_mb
# 1  cc197bad-dc9c-440d-a5b5-d52ba2e14234               Coldplay
# 2  a74b1b7f-71a5-4011-9441-d0b5e4122711              Radiohead
# 3  8bfac288-ccc5-448d-9573-c33ea2aa5c30  Red Hot Chili Peppers
# 4  73e5e69d-3554-40d8-8516-00cb38737a1c                Rihanna
#
#   artist_table.artist_lastfm artist_table.country_mb  \
# 0              artist_lastfm              country_mb
# 1                   Coldplay          United Kingdom
# 2                  Radiohead          United Kingdom
# 3      Red Hot Chili Peppers           United States
# 4                    Rihanna           United States
#
#   artist_table.country_lastfm  \
# 0              country_lastfm
# 1              United Kingdom
# 2              United Kingdom
# 3               United States
# 4     Barbados; United States
#
#                                 artist_table.tags_mb  \
# ...
